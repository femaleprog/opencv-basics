# %% [markdown]
# ### 1. Import dependencies

# %%
import cv2
import os

# %% [markdown]
# ### 2. Read in Image

# %%
img_path = 'opencv-4.9.0/opencv-4.9.0/data/images/bike.jpg'

# %%
img = cv2.imread(img_path)

# %%
img.shape # height width channels
# Out:
# (148, 229, 3)

# %% [markdown]
# ### 3. Render image

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tichi\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray)
plt.show()

# %% [markdown]
# ### 4. Write out image

# %%
cv2.imwrite('grayimg.jpg', gray)
# Out:
# True

# %%
output_path = 'C:\opencv\opencv-4.9.0\opencv-4.9.0\samples\data\outputgray.jpg'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\tichi\AppData\Local\Temp\ipykernel_25220\1636663128.py:1: SyntaxWarning: invalid escape sequence '\o'
#   output_path = 'C:\opencv\opencv-4.9.0\opencv-4.9.0\samples\data\outputgray.jpg'

# %%
cv2.imwrite(output_path,gray)
# Out:
# True
